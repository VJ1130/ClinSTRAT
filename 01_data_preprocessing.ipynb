# %%
# %pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in d:\Anaconda\envs\biostruct\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\Anaconda\envs\biostruct\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\Anaconda\envs\biostruct\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\Anaconda\envs\biostruct\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 3.0.5

# %%
df = pd.read_csv('brca_metabric/data_clinical_patient.txt', sep='\t', comment='#')
#sep='\t' specifies that the file is tab-separated, and comment='#' indicates that lines starting with '#' should be treated as comments and ignored.
clinical_patient = df
display(clinical_patient.head(n=10))
# Out:
#   PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY  \
# 0    MB-0000                           10.0  6.044         NaN           NO
# 1    MB-0002                            0.0  4.020        High           NO
# 2    MB-0005                            1.0  4.030        High          YES
# 3    MB-0006                            3.0  4.050    Moderate          YES
# 4    MB-0008                            8.0  6.080        High          YES
# 5    MB-0010                            0.0  4.062    Moderate           NO
# 6    MB-0014                            1.0  4.020    Moderate          YES
# 7    MB-0020                            NaN  6.130        High          YES
# 8    MB-0022                            1.0  4.058    Moderate           NO
# 9    MB-0025                           11.0  6.680         NaN          NaN
#
#    COHORT    ER_IHC HER2_SNP6 HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE  ...  \
# 0     1.0   Positve   NEUTRAL             YES                      Post  ...
# 1     1.0   Positve   NEUTRAL             YES                       Pre  ...
# 2     1.0   Positve   NEUTRAL             YES                       Pre  ...
# 3     1.0   Positve   NEUTRAL             YES                       Pre  ...
# 4     1.0   Positve   NEUTRAL             YES                      Post  ...
# 5     1.0   Positve   NEUTRAL             YES                      Post  ...
# 6     1.0   Positve      LOSS             YES                      Post  ...
# 7     1.0  Negative   NEUTRAL              NO                      Post  ...
# 8     1.0   Positve   NEUTRAL             YES                      Post  ...
# 9     1.0   Positve       NaN             NaN                       NaN  ...
#
#     OS_STATUS CLAUDIN_SUBTYPE              THREEGENE          VITAL_STATUS  \
# 0    0:LIVING     claudin-low              ER-/HER2-                Living
# 1    0:LIVING            LumA  ER+/HER2- High Prolif                Living
# 2  1:DECEASED            LumB                    NaN       Died of Disease
# 3    0:LIVING            LumB                    NaN                Living
# 4  1:DECEASED            LumB  ER+/HER2- High Prolif       Died of Disease
# 5  1:DECEASED            LumB  ER+/HER2- High Prolif       Died of Disease
# 6    0:LIVING            LumB                    NaN                Living
# 7  1:DECEASED          Normal              ER-/HER2-       Died of Disease
# 8  1:DECEASED     claudin-low                    NaN  Died of Other Causes
# 9         NaN             NaN                    NaN                   NaN
#
#   LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY  \
# 0      Right           YES           Ductal/NST         MASTECTOMY
# 1      Right           YES           Ductal/NST  BREAST CONSERVING
# 2      Right            NO           Ductal/NST         MASTECTOMY
# 3      Right           YES                Mixed         MASTECTOMY
# 4      Right           YES                Mixed         MASTECTOMY
# 5       Left           YES           Ductal/NST         MASTECTOMY
# 6      Right           YES           Ductal/NST  BREAST CONSERVING
# 7       Left           YES              Lobular         MASTECTOMY
# 8       Left           YES                Mixed  BREAST CONSERVING
# 9        NaN           NaN           Ductal/NST                NaN
#
#    RFS_MONTHS      RFS_STATUS
# 0  140.500000  0:Not Recurred
# 1   84.633333  0:Not Recurred
# 2  153.300000      1:Recurred
# 3  164.933333  0:Not Recurred
# 4   18.800000      1:Recurred
# 5    2.933333      1:Recurred
# 6  164.333333  0:Not Recurred
# 7   11.900000      1:Recurred
# 8   99.533333  0:Not Recurred
# 9  128.000000      1:Recurred
#
# [10 rows x 24 columns]

# %%
# the following line will display the summary information of the clinical_patient DataFrame, including the number of non-null entries, data types, and memory usage.
clinical_patient.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2509 entries, 0 to 2508
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PATIENT_ID                     2509 non-null   str
#  1   LYMPH_NODES_EXAMINED_POSITIVE  2243 non-null   float64
#  2   NPI                            2287 non-null   float64
#  3   CELLULARITY                    1917 non-null   str
#  4   CHEMOTHERAPY                   1980 non-null   str
#  5   COHORT                         2498 non-null   float64
#  6   ER_IHC                         2426 non-null   str
#  7   HER2_SNP6                      1980 non-null   str
#  8   HORMONE_THERAPY                1980 non-null   str
#  9   INFERRED_MENOPAUSAL_STATE      1980 non-null   str
#  10  SEX                            2509 non-null   str
#  11  INTCLUST                       1980 non-null   str
#  12  AGE_AT_DIAGNOSIS               2498 non-null   float64
#  13  OS_MONTHS                      1981 non-null   float64
#  14  OS_STATUS                      1981 non-null   str
#  15  CLAUDIN_SUBTYPE                1980 non-null   str
#  16  THREEGENE                      1764 non-null   str
#  17  VITAL_STATUS                   1980 non-null   str
#  18  LATERALITY                     1870 non-null   str
#  19  RADIO_THERAPY                  1980 non-null   str
#  20  HISTOLOGICAL_SUBTYPE           2374 non-null   str
#  21  BREAST_SURGERY                 1955 non-null   str
#  22  RFS_MONTHS                     2388 non-null   float64
#  23  RFS_STATUS                     2488 non-null   str
# dtypes: float64(6), str(18)
# memory usage: 470.6 KB

# %%
# Subset the dataframe
#.copy() is used to create a new DataFrame that is a copy of the selected columns from the original DataFrame. This is important to avoid SettingWithCopyWarning in pandas, which can occur when trying to modify a slice of a DataFrame.
clinical_baseline = clinical_patient.copy()
display(clinical_baseline.head())
# Out:
#   PATIENT_ID  LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY  \
# 0    MB-0000                           10.0  6.044         NaN           NO
# 1    MB-0002                            0.0  4.020        High           NO
# 2    MB-0005                            1.0  4.030        High          YES
# 3    MB-0006                            3.0  4.050    Moderate          YES
# 4    MB-0008                            8.0  6.080        High          YES
#
#    COHORT   ER_IHC HER2_SNP6 HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE  ...  \
# 0     1.0  Positve   NEUTRAL             YES                      Post  ...
# 1     1.0  Positve   NEUTRAL             YES                       Pre  ...
# 2     1.0  Positve   NEUTRAL             YES                       Pre  ...
# 3     1.0  Positve   NEUTRAL             YES                       Pre  ...
# 4     1.0  Positve   NEUTRAL             YES                      Post  ...
#
#     OS_STATUS CLAUDIN_SUBTYPE              THREEGENE     VITAL_STATUS  \
# 0    0:LIVING     claudin-low              ER-/HER2-           Living
# 1    0:LIVING            LumA  ER+/HER2- High Prolif           Living
# 2  1:DECEASED            LumB                    NaN  Died of Disease
# 3    0:LIVING            LumB                    NaN           Living
# 4  1:DECEASED            LumB  ER+/HER2- High Prolif  Died of Disease
#
#   LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY  \
# 0      Right           YES           Ductal/NST         MASTECTOMY
# 1      Right           YES           Ductal/NST  BREAST CONSERVING
# 2      Right            NO           Ductal/NST         MASTECTOMY
# 3      Right           YES                Mixed         MASTECTOMY
# 4      Right           YES                Mixed         MASTECTOMY
#
#    RFS_MONTHS      RFS_STATUS
# 0  140.500000  0:Not Recurred
# 1   84.633333  0:Not Recurred
# 2  153.300000      1:Recurred
# 3  164.933333  0:Not Recurred
# 4   18.800000      1:Recurred
#
# [5 rows x 24 columns]

# %%
# 1. Define the target variable (y) from the clean clinical_patient DataFrame.
y = clinical_baseline['CLAUDIN_SUBTYPE']

# 2. Define the feature matrix (X) by dropping the columns that are not needed for the model.
cols_to_drop = [
    'PATIENT_ID',
    'CLAUDIN_SUBTYPE',  # Target variable
    'THREEGENE', 'COHORT', 'HER2_SNP6',  # Target leakage
    'OS_MONTHS', 'OS_STATUS',
    'RFS_MONTHS', 'RFS_STATUS', 'VITAL_STATUS',  # Endpoints / Validation
    'SEX'  # Uninformative constant
]


# 3. Create feature matrix (X) by dropping the specified columns from the clean clinical_patient DataFrame.
X = clinical_baseline.drop(columns=cols_to_drop, inplace=False) #inplace=False ensures that the original DataFrame is not modified, and a new DataFrame is returned instead.
display(X.head(n=10))
# Out:
#    LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY    ER_IHC  \
# 0                           10.0  6.044         NaN           NO   Positve
# 1                            0.0  4.020        High           NO   Positve
# 2                            1.0  4.030        High          YES   Positve
# 3                            3.0  4.050    Moderate          YES   Positve
# 4                            8.0  6.080        High          YES   Positve
# 5                            0.0  4.062    Moderate           NO   Positve
# 6                            1.0  4.020    Moderate          YES   Positve
# 7                            NaN  6.130        High          YES  Negative
# 8                            1.0  4.058    Moderate           NO   Positve
# 9                           11.0  6.680         NaN          NaN   Positve
#
#   HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE INTCLUST  AGE_AT_DIAGNOSIS  \
# 0             YES                      Post     4ER+             75.65
# 1             YES                       Pre     4ER+             43.19
# 2             YES                       Pre        3             48.87
# 3             YES                       Pre        9             47.68
# 4             YES                      Post        9             76.97
# 5             YES                      Post        7             78.77
# 6             YES                      Post        3             56.45
# 7              NO                      Post     4ER-             70.00
# 8             YES                      Post        3             89.08
# 9             NaN                       NaN      NaN             76.24
#
#   LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY
# 0      Right           YES           Ductal/NST         MASTECTOMY
# 1      Right           YES           Ductal/NST  BREAST CONSERVING
# 2      Right            NO           Ductal/NST         MASTECTOMY
# 3      Right           YES                Mixed         MASTECTOMY
# 4      Right           YES                Mixed         MASTECTOMY
# 5       Left           YES           Ductal/NST         MASTECTOMY
# 6      Right           YES           Ductal/NST  BREAST CONSERVING
# 7       Left           YES              Lobular         MASTECTOMY
# 8       Left           YES                Mixed  BREAST CONSERVING
# 9        NaN           NaN           Ductal/NST                NaN

# %%
print("Shape of feature matrix (X):", X.shape)

print("Shape of target variable (y):", y.shape)
print("Target class counts:\n", y.value_counts())
print(y.value_counts(normalize=True))  # Display class distribution as percentages
print(y.value_counts(dropna=False))  # Display class distribution including NaN values
display(X.head(n=10))
# Out:
# Shape of feature matrix (X): (2509, 13)
# Shape of target variable (y): (2509,)
# Target class counts:
#  CLAUDIN_SUBTYPE
# LumA           700
# LumB           475
# Her2           224
# claudin-low    218
# Basal          209
# Normal         148
# NC               6
# Name: count, dtype: int64
# CLAUDIN_SUBTYPE
# LumA           0.353535
# LumB           0.239899
# Her2           0.113131
# claudin-low    0.110101
# Basal          0.105556
# Normal         0.074747
# NC             0.003030
# Name: proportion, dtype: float64
# CLAUDIN_SUBTYPE
# LumA           700
# NaN            529
# LumB           475
# Her2           224
# claudin-low    218
# Basal          209
# Normal         148
# NC               6
# Name: count, dtype: int64
#    LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY    ER_IHC  \
# 0                           10.0  6.044         NaN           NO   Positve
# 1                            0.0  4.020        High           NO   Positve
# 2                            1.0  4.030        High          YES   Positve
# 3                            3.0  4.050    Moderate          YES   Positve
# 4                            8.0  6.080        High          YES   Positve
# 5                            0.0  4.062    Moderate           NO   Positve
# 6                            1.0  4.020    Moderate          YES   Positve
# 7                            NaN  6.130        High          YES  Negative
# 8                            1.0  4.058    Moderate           NO   Positve
# 9                           11.0  6.680         NaN          NaN   Positve
#
#   HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE INTCLUST  AGE_AT_DIAGNOSIS  \
# 0             YES                      Post     4ER+             75.65
# 1             YES                       Pre     4ER+             43.19
# 2             YES                       Pre        3             48.87
# 3             YES                       Pre        9             47.68
# 4             YES                      Post        9             76.97
# 5             YES                      Post        7             78.77
# 6             YES                      Post        3             56.45
# 7              NO                      Post     4ER-             70.00
# 8             YES                      Post        3             89.08
# 9             NaN                       NaN      NaN             76.24
#
#   LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY
# 0      Right           YES           Ductal/NST         MASTECTOMY
# 1      Right           YES           Ductal/NST  BREAST CONSERVING
# 2      Right            NO           Ductal/NST         MASTECTOMY
# 3      Right           YES                Mixed         MASTECTOMY
# 4      Right           YES                Mixed         MASTECTOMY
# 5       Left           YES           Ductal/NST         MASTECTOMY
# 6      Right           YES           Ductal/NST  BREAST CONSERVING
# 7       Left           YES              Lobular         MASTECTOMY
# 8       Left           YES                Mixed  BREAST CONSERVING
# 9        NaN           NaN           Ductal/NST                NaN

# %%
# Check for missing values in the feature matrix (X)
missing_values = X.isnull().sum()
print("Missing values in each column:\n", missing_values)
X.dtypes
# Out:
# Missing values in each column:
#  LYMPH_NODES_EXAMINED_POSITIVE    266
# NPI                              222
# CELLULARITY                      592
# CHEMOTHERAPY                     529
# ER_IHC                            83
# HORMONE_THERAPY                  529
# INFERRED_MENOPAUSAL_STATE        529
# INTCLUST                         529
# AGE_AT_DIAGNOSIS                  11
# LATERALITY                       639
# RADIO_THERAPY                    529
# HISTOLOGICAL_SUBTYPE             135
# BREAST_SURGERY                   554
# dtype: int64
# LYMPH_NODES_EXAMINED_POSITIVE    float64
# NPI                              float64
# CELLULARITY                          str
# CHEMOTHERAPY                         str
# ER_IHC                               str
# HORMONE_THERAPY                      str
# INFERRED_MENOPAUSAL_STATE            str
# INTCLUST                             str
# AGE_AT_DIAGNOSIS                 float64
# LATERALITY                           str
# RADIO_THERAPY                        str
# HISTOLOGICAL_SUBTYPE                 str
# BREAST_SURGERY                       str
# dtype: object

# %%
# Cleaning the feature matrix (x) without dropping any columns, using 
# impute[] = method is used to fill in missing values in the feature matrix by replacing them with the mean value of the respective column.
#X['LYMPH_NODES_EXAMINED_POSITIVE'].dtype
#X['LYMPH_NODES_EXAMINED_POSITIVE'] = X['LYMPH_NODES_EXAMINED_POSITIVE'].fillna(X['LYMPH_NODES_EXAMINED_POSITIVE'].median())
#display(X.head(n=10))

# %%
mode_value = X['LYMPH_NODES_EXAMINED_POSITIVE'].mode()
print(mode_value)
# Out:
# 0    0.0
# Name: LYMPH_NODES_EXAMINED_POSITIVE, dtype: float64

# %%
# Display descriptive statistics for numerical columns
display(X.describe())
# Out:
#        LYMPH_NODES_EXAMINED_POSITIVE          NPI  AGE_AT_DIAGNOSIS
# count                    2243.000000  2287.000000       2498.000000
# mean                        1.950513     4.028787         60.420300
# std                         4.017774     1.189092         13.032997
# min                         0.000000     1.000000         21.930000
# 25%                         0.000000     3.048000         50.920000
# 50%                         0.000000     4.044000         61.110000
# 75%                         2.000000     5.040000         70.000000
# max                        45.000000     7.200000         96.290000

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\Anaconda\envs\biostruct\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\Anaconda\envs\biostruct\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\Anaconda\envs\biostruct\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\Anaconda\envs\biostruct\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in d:\Anaconda\envs\biostruct\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\Anaconda\envs\biostruct\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\Anaconda\envs\biostruct\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\Anaconda\envs\biostruct\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\Anaconda\envs\biostruct\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\Anaconda\envs\biostruct\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.4.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in d:\Anaconda\envs\biostruct\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in d:\Anaconda\envs\biostruct\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %%
# Impute missing values in continuous columns using KNN imputation
num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
# .tolist() converts the Index object returned by select_dtypes into a regular Python list, which is often easier to work with for further processing or analysis.
knn_imputer = KNNImputer(n_neighbors=5)  # You can adjust n_neighbors based on your dataset
X[num_cols] = knn_imputer.fit_transform(X[num_cols])
print("Missing values in continuous columns after KNN imputation:")
print(X[num_cols].isnull().sum())
# Out:
# Missing values in continuous columns after KNN imputation:
# LYMPH_NODES_EXAMINED_POSITIVE    0
# NPI                              0
# AGE_AT_DIAGNOSIS                 0
# dtype: int64

# %%
display(X.head(n=10))
# Out:
#    LYMPH_NODES_EXAMINED_POSITIVE    NPI CELLULARITY CHEMOTHERAPY    ER_IHC  \
# 0                           10.0  6.044         NaN           NO   Positve
# 1                            0.0  4.020        High           NO   Positve
# 2                            1.0  4.030        High          YES   Positve
# 3                            3.0  4.050    Moderate          YES   Positve
# 4                            8.0  6.080        High          YES   Positve
# 5                            0.0  4.062    Moderate           NO   Positve
# 6                            1.0  4.020    Moderate          YES   Positve
# 7                            8.6  6.130        High          YES  Negative
# 8                            1.0  4.058    Moderate           NO   Positve
# 9                           11.0  6.680         NaN          NaN   Positve
#
#   HORMONE_THERAPY INFERRED_MENOPAUSAL_STATE INTCLUST  AGE_AT_DIAGNOSIS  \
# 0             YES                      Post     4ER+             75.65
# 1             YES                       Pre     4ER+             43.19
# 2             YES                       Pre        3             48.87
# 3             YES                       Pre        9             47.68
# 4             YES                      Post        9             76.97
# 5             YES                      Post        7             78.77
# 6             YES                      Post        3             56.45
# 7              NO                      Post     4ER-             70.00
# 8             YES                      Post        3             89.08
# 9             NaN                       NaN      NaN             76.24
#
#   LATERALITY RADIO_THERAPY HISTOLOGICAL_SUBTYPE     BREAST_SURGERY
# 0      Right           YES           Ductal/NST         MASTECTOMY
# 1      Right           YES           Ductal/NST  BREAST CONSERVING
# 2      Right            NO           Ductal/NST         MASTECTOMY
# 3      Right           YES                Mixed         MASTECTOMY
# 4      Right           YES                Mixed         MASTECTOMY
# 5       Left           YES           Ductal/NST         MASTECTOMY
# 6      Right           YES           Ductal/NST  BREAST CONSERVING
# 7       Left           YES              Lobular         MASTECTOMY
# 8       Left           YES                Mixed  BREAST CONSERVING
# 9        NaN           NaN           Ductal/NST                NaN

# %%
# Distribution analysis of numerical columns using histograms and KDE plots 
# what are kde plots? KDE stands for Kernel Density Estimation. It is a non-parametric way to estimate the probability density function of a random variable. In simpler terms, KDE plots provide a smoothed curve that represents the distribution of data points in a dataset. Unlike histograms, which can be blocky and depend on bin sizes, KDE plots offer a continuous and smooth representation of the data distribution.
import matplotlib.pyplot as plt
import seaborn as sns

# Get numerical columns again, excluding the target variable if it's binary
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
# Assuming 'data_clinical_basline' is the target and we might not want its distribution histogram in the same way

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i) # Adjust subplot grid as needed
    sns.histplot(X[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
what do I do next?Next, you can proceed with the following steps in your data preprocessing and analysis workflow:1. **Feature Engineering**: Create new features or transform existing ones to improve model performance. This could include encoding categorical variables, creating interaction terms, or normalizing/standardizing numerical features.
